# %% [markdown]
# **Uncomment the cell below if running on Google Colab or Kaggle**

# %%
# %%capture
# !pip3 install -U torch torchvision torchaudio
# !pip3 install -U fastai

# %% [markdown]
# **Import dependencies**

# %%
from fastai.vision.all import *

# %%
import inspect
import pandas as pd
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def inspect_default_args(target, annotations: bool=False):
    # Get the argument names
    args = inspect.getfullargspec(target).args
    # Get the default values
    defaults = inspect.getfullargspec(target).defaults

    index = ["Default Value"]

    # Pad defaults
    defaults = [None]*(len(args)-len(defaults)) + list(defaults)
    if annotations:
        index.append("Annotation")
        annotations = inspect.getfullargspec(target).annotations.values()
        # Pad annotations
        annotations = [None]*(len(args)-len(annotations)) + list(annotations)
        default_args = {arg:[df, annot] for arg,df,annot in zip(args, defaults, annotations)}
    else:
        default_args = {arg:[default] for arg,default in zip(args, defaults)}
        
    return pd.DataFrame(default_args, index=index).T

# %% [markdown]
# **Define path to dataset**

# %%
path = untar_data(URLs.PETS)

# %%
path.ls()
# Out:
# (#3) [Path('/home/innom-dt/.fastai/data/oxford-iiit-pet/models'),Path('/home/innom-dt/.fastai/data/oxford-iiit-pet/annotations'),Path('/home/innom-dt/.fastai/data/oxford-iiit-pet/images')]

# %%
files = get_image_files(path/"images")
len(files)
# Out:
# 7390

# %% [markdown]
# **Define Lables**

# %%
files[0], files[6]
# Out:
# (Path('/home/innom-dt/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_19.jpg'),
#  Path('/home/innom-dt/.fastai/data/oxford-iiit-pet/images/Sphynx_89.jpg'))

# %%
files[0].name
# Out:
# 'wheaten_terrier_19.jpg'

# %%
# Pattern to extract the pet breed from the file name
pat = r'^(.*)_\d+.jpg'

# %% [markdown]
# **Define Getters**

# %%
inspect_default_args(get_image_files)
# Out:
#         Default Value
# path             None
# recurse          True
# folders          None

# %%
get_items = get_image_files
get_y = using_attr(RegexLabeller(pat), 'name')

# %% [markdown]
# **Define Transforms**

# %%
item_tfms = [Resize(224)]
batch_tfms = aug_transforms(size=224)

# %% [markdown]
# **Define custom DataBlock**

# %%
pets = DataBlock(blocks=(ImageBlock, CategoryBlock),
                 get_items=get_items,
                 splitter=RandomSplitter(),
                 get_y=get_y,
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms)

# %% [markdown]
# **Define batch size**

# %%
bs = 128

# %% [markdown]
# **Define DataLoaders object**

# %%
dls = pets.dataloaders(path/'images', bs=bs)

# %% [markdown]
# **Verify DataLoaders object**

# %%
dls.show_batch()

# %% [markdown]
# **Inspect Learner parameters**

# %%
inspect_default_args(vision_learner)
# Out:
#                                             Default Value
# dls                                                  None
# arch                                                 None
# normalize                                            True
# n_out                                                None
# pretrained                                           True
# loss_func                                            None
# opt_func                <function Adam at 0x7f28417425f0>
# lr                                                  0.001
# splitter                                             None
# cbs                                                  None
# metrics                                              None
# path                                                 None
# model_dir                                          models
# wd                                                   None
# wd_bn_bias                                          False
# train_bn                                             True
# moms                                   (0.95, 0.85, 0.95)
# cut                                                  None
# n_in                                                    3
# init         <function kaiming_normal_ at 0x7f285a583be0>
# custom_head                                          None
# concat_pool                                          True
# lin_ftrs                                             None
# ps                                                    0.5
# pool                                                 True
# first_bn                                             True
# bn_final                                            False
# lin_first                                           False
# y_range                                              None

# %% [markdown]
# **Define model**

# %%
model = resnet18

# %% [markdown]
# **Define [metrics](https://docs.fast.ai/metrics.html)**

# %%
metrics = [error_rate, accuracy]

# %% [markdown]
# **Define Learner object**

# %%
learn = vision_learner(dls, model, metrics=metrics).to_fp16()

# %% [markdown]
# **Find learning rate**

# %%
inspect_default_args(learn.lr_find)
# Out:
#                                      Default Value
# self                                          None
# start_lr                                       0.0
# end_lr                                          10
# num_it                                         100
# stop_div                                      True
# show_plot                                     True
# suggest_funcs  <function valley at 0x7f2841491750>

# %% [markdown]
# **Define [suggestion methods](https://docs.fast.ai/callback.schedule.html#Suggestion-Methods)**

# %%
suggest_funcs = [valley, minimum, steep]

# %%
learn.lr_find(suggest_funcs=suggest_funcs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0014454397605732083, minimum=0.012022644281387329, steep=0.005248074419796467)

# %% [markdown]
# **Define learning rate**

# %%
lr = 2e-3
lr
# Out:
# 0.002

# %% [markdown]
# **Define number of epochs**

# %%
epochs = 2

# %% [markdown]
# **Fine tune model**

# %%
inspect_default_args(learn.fine_tune)
# Out:
#               Default Value
# self                   None
# epochs                 None
# base_lr               0.002
# freeze_epochs             1
# lr_mult                 100
# pct_start               0.3
# div                     5.0
# lr_max                 None
# div_final          100000.0
# wd                     None
# moms                   None
# cbs                    None
# reset_opt             False

# %%
learn.fine_tune(epochs, base_lr=lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.251075</td>
#       <td>0.421435</td>
#       <td>0.138024</td>
#       <td>0.861976</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.576800</td>
#       <td>0.312111</td>
#       <td>0.089986</td>
#       <td>0.910014</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.428787</td>
#       <td>0.267478</td>
#       <td>0.086604</td>
#       <td>0.913396</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Select a test image**

# %%
import PIL

# %%
test_file = files[0]
test_file.name
# Out:
# 'wheaten_terrier_19.jpg'

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %% [markdown]
# **Make a prediction on a single image using a file path**

# %%
learn.predict(test_file)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('wheaten_terrier',
#  TensorBase(35),
#  TensorBase([7.7206e-07, 1.2495e-06, 7.9242e-06, 1.9350e-07, 2.0561e-06, 3.3696e-07,
#          6.0269e-06, 4.7440e-05, 7.8882e-07, 2.0722e-06, 8.0674e-07, 1.4795e-06,
#          1.6637e-05, 1.1296e-05, 1.3804e-06, 2.3596e-06, 3.4173e-06, 1.8317e-08,
#          1.8910e-04, 7.6579e-06, 1.3614e-07, 7.1484e-06, 5.1604e-04, 2.0601e-06,
#          6.3943e-07, 1.6408e-06, 8.5292e-07, 2.3242e-06, 6.8057e-08, 3.0737e-06,
#          1.6154e-06, 1.4159e-06, 5.6353e-03, 2.4461e-07, 9.3037e-07, 9.9320e-01,
#          3.2419e-04]))

# %% [markdown]
# **Make a prediction on a single image using a [fastai.vision.core.PILImage](https://docs.fast.ai/vision.core.html#PILImage)**

# %%
learn.predict(PILImage(test_img))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('wheaten_terrier',
#  TensorBase(35),
#  TensorBase([7.7206e-07, 1.2495e-06, 7.9242e-06, 1.9350e-07, 2.0561e-06, 3.3696e-07,
#          6.0269e-06, 4.7440e-05, 7.8882e-07, 2.0722e-06, 8.0674e-07, 1.4795e-06,
#          1.6637e-05, 1.1296e-05, 1.3804e-06, 2.3596e-06, 3.4173e-06, 1.8317e-08,
#          1.8910e-04, 7.6579e-06, 1.3614e-07, 7.1484e-06, 5.1604e-04, 2.0601e-06,
#          6.3943e-07, 1.6408e-06, 8.5292e-07, 2.3242e-06, 6.8057e-08, 3.0737e-06,
#          1.6154e-06, 1.4159e-06, 5.6353e-03, 2.4461e-07, 9.3037e-07, 9.9320e-01,
#          3.2419e-04]))

# %% [markdown]
# **Make a prediction on a single image using a [fastai.torch_core.tensor](https://docs.fast.ai/torch_core.html#tensor)**

# %%
learn.predict(tensor(test_img))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('wheaten_terrier',
#  TensorBase(35),
#  TensorBase([7.7206e-07, 1.2495e-06, 7.9242e-06, 1.9350e-07, 2.0561e-06, 3.3696e-07,
#          6.0269e-06, 4.7440e-05, 7.8882e-07, 2.0722e-06, 8.0674e-07, 1.4795e-06,
#          1.6637e-05, 1.1296e-05, 1.3804e-06, 2.3596e-06, 3.4173e-06, 1.8317e-08,
#          1.8910e-04, 7.6579e-06, 1.3614e-07, 7.1484e-06, 5.1604e-04, 2.0601e-06,
#          6.3943e-07, 1.6408e-06, 8.5292e-07, 2.3242e-06, 6.8057e-08, 3.0737e-06,
#          1.6154e-06, 1.4159e-06, 5.6353e-03, 2.4461e-07, 9.3037e-07, 9.9320e-01,
#          3.2419e-04]))

# %% [markdown]
# **Make predictions for a group of images**

# %%
inspect_default_args(learn.show_results)
# Out:
#         Default Value
# self             None
# ds_idx              1
# dl               None
# max_n               9
# shuffle          True

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Define an Interpretation object**

# %%
inspect_default_args(Interpretation.from_learner)
# Out:
#        Default Value
# cls             None
# learn           None
# ds_idx             1
# dl              None
# act             None

# %%
interp = Interpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Plot top losses**

# %%
inspect_default_args(interp.plot_top_losses)
# Out:
#         Default Value
# self             None
# k                None
# largest          True

# %%
interp.plot_top_losses(k=9, figsize=(15,10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.dls.after_item
# Out:
# Pipeline: Resize -- {'size': (224, 224), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (<Resampling.BILINEAR: 2>, 0), 'p': 1.0} -> ToTensor

# %%
learn.dls.after_batch
# Out:
# Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} -> Flip -- {'size': 224, 'mode': 'bilinear', 'pad_mode': 'reflection', 'mode_mask': 'nearest', 'align_corners': True, 'p': 0.5} -> Brightness -- {'max_lighting': 0.2, 'p': 1.0, 'draw': None, 'batch': False} -> Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)}

# %%
learn.dls.vocab
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']

# %% [markdown]
# **Reset test image**

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
test_img.size
# Out:
# (500, 333)

# %%
min(test_img.size)
# Out:
# 333

# %%
min_dim = test_img.size.index(min(test_img.size))
max_dim = 1 - min_dim

# %%
target_dim = 224

# %% [markdown]
# **Set input dims**

# %%
inp_dims = [0,0]
inp_dims[min_dim] = target_dim
inp_dims[max_dim] = int(test_img.size[max_dim] / (test_img.size[min_dim]/target_dim))
inp_dims
# Out:
# [336, 224]

# %%
resized_img = test_img.resize(inp_dims)
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=336x224>

# %% [markdown]
# **Convert image to tensor**

# %%
img_tensor = tensor(resized_img).permute(2, 0, 1)
img_tensor.shape, img_tensor
# Out:
# (torch.Size([3, 224, 336]),
#  tensor([[[168, 176, 177,  ...,  50,  50,  49],
#           [166, 176, 179,  ...,  49,  47,  46],
#           [166, 175, 182,  ...,  45,  43,  43],
#           ...,
#           [118, 120, 110,  ..., 147, 150, 147],
#           [103, 105, 104,  ..., 144, 148, 149],
#           [ 94, 106, 113,  ..., 141, 146, 149]],
#
#          [[125, 137, 136,  ...,  22,  23,  24],
#           [126, 135, 134,  ...,  20,  21,  22],
#           [130, 134, 135,  ...,  23,  23,  22],
#           ...,
#           [ 73,  68,  66,  ...,  63,  65,  61],
#           [ 64,  56,  55,  ...,  63,  64,  65],
#           [ 52,  53,  56,  ...,  57,  60,  64]],
#
#          [[ 83,  85,  83,  ...,  15,  14,  14],
#           [ 77,  84,  85,  ...,  16,  17,  17],
#           [ 79,  83,  86,  ...,  16,  15,  17],
#           ...,
#           [ 44,  43,  39,  ...,  41,  42,  39],
#           [ 40,  35,  34,  ...,  40,  41,  40],
#           [ 31,  35,  38,  ...,  36,  40,  41]]], dtype=torch.uint8))

# %% [markdown]
# **Scale tensor values**

# %%
scaled_tensor = img_tensor.float().div_(255)

# %% [markdown]
# **Prepare imagenet mean values**

# %%
mean_tensor = tensor(imagenet_stats[0]).view(1,1,-1).permute(2, 0, 1)
mean_tensor.shape, mean_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]))

# %% [markdown]
# **Prepare imagenet std values**

# %%
std_tensor = tensor(imagenet_stats[1]).view(1,1,-1).permute(2, 0, 1)
std_tensor.shape, std_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]))

# %% [markdown]
# **Normalize and batch image tensor**

# %%
normalized_tensor = (scaled_tensor - mean_tensor) / std_tensor
batched_tensor = normalized_tensor.unsqueeze(dim=0)
batched_tensor.shape, batched_tensor
# Out:
# (torch.Size([1, 3, 224, 336]),
#  tensor([[[[ 0.7591,  0.8961,  0.9132,  ..., -1.2617, -1.2617, -1.2788],
#            [ 0.7248,  0.8961,  0.9474,  ..., -1.2788, -1.3130, -1.3302],
#            [ 0.7248,  0.8789,  0.9988,  ..., -1.3473, -1.3815, -1.3815],
#            ...,
#            [-0.0972, -0.0629, -0.2342,  ...,  0.3994,  0.4508,  0.3994],
#            [-0.3541, -0.3198, -0.3369,  ...,  0.3481,  0.4166,  0.4337],
#            [-0.5082, -0.3027, -0.1828,  ...,  0.2967,  0.3823,  0.4337]],
#
#           [[ 0.1527,  0.3627,  0.3452,  ..., -1.6506, -1.6331, -1.6155],
#            [ 0.1702,  0.3277,  0.3102,  ..., -1.6856, -1.6681, -1.6506],
#            [ 0.2402,  0.3102,  0.3277,  ..., -1.6331, -1.6331, -1.6506],
#            ...,
#            [-0.7577, -0.8452, -0.8803,  ..., -0.9328, -0.8978, -0.9678],
#            [-0.9153, -1.0553, -1.0728,  ..., -0.9328, -0.9153, -0.8978],
#            [-1.1253, -1.1078, -1.0553,  ..., -1.0378, -0.9853, -0.9153]],
#
#           [[-0.3578, -0.3230, -0.3578,  ..., -1.5430, -1.5604, -1.5604],
#            [-0.4624, -0.3404, -0.3230,  ..., -1.5256, -1.5081, -1.5081],
#            [-0.4275, -0.3578, -0.3055,  ..., -1.5256, -1.5430, -1.5081],
#            ...,
#            [-1.0376, -1.0550, -1.1247,  ..., -1.0898, -1.0724, -1.1247],
#            [-1.1073, -1.1944, -1.2119,  ..., -1.1073, -1.0898, -1.1073],
#            [-1.2641, -1.1944, -1.1421,  ..., -1.1770, -1.1073, -1.0898]]]]))

# %% [markdown]
# **Pass tensor to model**

# %%
with torch.no_grad():
    preds = learn.model(batched_tensor.cuda())
preds
# Out:
# TensorBase([[-1.8572, -0.7146,  1.4786, -2.5048, -0.6607, -1.8409,  1.4642,  3.5464,
#          -0.1703, -0.5889, -1.2390, -1.2690,  1.7021,  0.4049, -0.6933, -0.9447,
#          -0.4018, -3.7554,  3.8522,  2.6074, -3.1186,  1.5600,  4.0249,  0.2305,
#          -2.1502, -1.2607, -1.8573, -0.8758, -3.0033, -0.4763, -0.1918, -1.3608,
#           5.6468, -2.0728, -2.3387,  8.3023,  3.0448]], device='cuda:0')

# %%
torch.nn.functional.softmax(preds, dim=1)
# Out:
# TensorBase([[3.4550e-05, 1.0831e-04, 9.7089e-04, 1.8081e-05, 1.1430e-04, 3.5119e-05,
#          9.5697e-04, 7.6769e-03, 1.8666e-04, 1.2282e-04, 6.4108e-05, 6.2215e-05,
#          1.2140e-03, 3.3179e-04, 1.1064e-04, 8.6052e-05, 1.4809e-04, 5.1772e-06,
#          1.0423e-02, 3.0018e-03, 9.7869e-06, 1.0532e-03, 1.2388e-02, 2.7868e-04,
#          2.5775e-05, 6.2736e-05, 3.4546e-05, 9.2188e-05, 1.0982e-05, 1.3746e-04,
#          1.8269e-04, 5.6760e-05, 6.2721e-02, 2.7848e-05, 2.1346e-05, 8.9258e-01,
#          4.6490e-03]], device='cuda:0')

# %% [markdown]
# **Process model output**

# %%
preds.argmax()
# Out:
# TensorBase(35, device='cuda:0')

# %%
torch.nn.functional.softmax(preds, dim=1)[0][preds.argmax()]
# Out:
# TensorBase(0.8926, device='cuda:0')

# %%
learn.dls.vocab[preds.argmax()]
# Out:
# 'wheaten_terrier'

# %%
learn.dls.vocab[torch.nn.functional.softmax(preds, dim=1).argmax()]
# Out:
# 'wheaten_terrier'

# %% [markdown]
# **Define ONNX file name**

# %%
onnx_file_name = f"{path.name}-{learn.arch.__name__}.onnx"
onnx_file_name
# Out:
# 'oxford-iiit-pet-resnet18.onnx'

# %% [markdown]
# **Export trained model to ONNX**

# %%
torch.onnx.export(learn.model.cpu(),
                  batched_tensor,
                  onnx_file_name,
                  export_params=True,
                  opset_version=9,
                  do_constant_folding=True,
                  input_names = ['input'],
                  output_names = ['output'],
                  # Uncomment the line below to unlock input dimensions
                  #dynamic_axes={'input': {2 : 'height', 3 : 'width'}}
                 )
