# %% [markdown]
# **Uncomment the cell below if running on Google Colab or Kaggle**

# %%
# %%capture
# !pip3 install -U torch torchvision torchaudio
# !pip3 install -U fastai

# %% [markdown]
# **Import dependencies**

# %%
from fastai.vision.all import *

# %%
import inspect
import pandas as pd
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def inspect_default_args(target, annotations: bool=False):
    # Get the argument names
    args = inspect.getfullargspec(target).args
    # Get the default values
    defaults = inspect.getfullargspec(target).defaults

    index = ["Default Value"]

    # Pad defaults
    defaults = [None]*(len(args)-len(defaults)) + list(defaults)
    if annotations:
        index.append("Annotation")
        annotations = inspect.getfullargspec(target).annotations.values()
        # Pad annotations
        annotations = [None]*(len(args)-len(annotations)) + list(annotations)
        default_args = {arg:[df, annot] for arg,df,annot in zip(args, defaults, annotations)}
    else:
        default_args = {arg:[default] for arg,default in zip(args, defaults)}
        
    return pd.DataFrame(default_args, index=index).T

# %% [markdown]
# **Define path to dataset**

# %%
path = untar_data(URLs.PASCAL_2007)

# %%
path.ls()
# Out:
# (#9) [Path('/home/innom-dt/.fastai/data/pascal_2007/segmentation'),Path('/home/innom-dt/.fastai/data/pascal_2007/test'),Path('/home/innom-dt/.fastai/data/pascal_2007/valid.json'),Path('/home/innom-dt/.fastai/data/pascal_2007/models'),Path('/home/innom-dt/.fastai/data/pascal_2007/train'),Path('/home/innom-dt/.fastai/data/pascal_2007/test.csv'),Path('/home/innom-dt/.fastai/data/pascal_2007/train.json'),Path('/home/innom-dt/.fastai/data/pascal_2007/train.csv'),Path('/home/innom-dt/.fastai/data/pascal_2007/test.json')]

# %% [markdown]
# **Get Lables**

# %%
# !head $path/'train.csv'
# Out:
# fname,labels,is_valid
# 000005.jpg,chair,True
# 000007.jpg,car,True
# 000009.jpg,horse person,True
# 000012.jpg,car,False
# 000016.jpg,bicycle,True
# 000017.jpg,person horse,False
# 000019.jpg,cat,True
# 000020.jpg,car,True
# 000021.jpg,dog person,True

# %%
# !tail -n +2 $path/'train.csv' | wc -l
# Out:
# 5011

# %%
df = pd.read_csv(path/'train.csv')
df.head()
# Out:
#         fname        labels  is_valid
# 0  000005.jpg         chair      True
# 1  000007.jpg           car      True
# 2  000009.jpg  horse person      True
# 3  000012.jpg           car     False
# 4  000016.jpg       bicycle      True

# %% [markdown]
# **Define Splitter**

# %%
splitter = ColSplitter('is_valid')

# %% [markdown]
# **Define Getters**

# %%
inspect_default_args(ColReader)
# Out:
#             Default Value
# self                 None
# cols                 None
# pref
# suff
# label_delim          None

# %%
get_x = ColReader('fname', pref=str(path/'train') + os.path.sep)
get_y = ColReader('labels', label_delim=' ')

# %% [markdown]
# **Define Transforms**

# %%
item_tfms = [Resize(460)]
batch_tfms = aug_transforms(size=224)

# %% [markdown]
# **Define custom DataBlock**

# %%
pascal = DataBlock(blocks=(ImageBlock, MultiCategoryBlock),
                   splitter=splitter,
                   get_x=get_x,
                   get_y=get_y,
                   item_tfms=item_tfms,
                   batch_tfms=batch_tfms
                  )

# %% [markdown]
# **Define batch size**

# %%
bs = 128

# %% [markdown]
# **Define DataLoaders object**

# %%
dls = pascal.dataloaders(df, bs=bs)

# %% [markdown]
# **Verify DataLoaders object**

# %%
dls.show_batch()

# %% [markdown]
# **Inspect Learner parameters**

# %%
inspect_default_args(vision_learner)
# Out:
#                                             Default Value
# dls                                                  None
# arch                                                 None
# normalize                                            True
# n_out                                                None
# pretrained                                           True
# loss_func                                            None
# opt_func                <function Adam at 0x7f49907ba5f0>
# lr                                                  0.001
# splitter                                             None
# cbs                                                  None
# metrics                                              None
# path                                                 None
# model_dir                                          models
# wd                                                   None
# wd_bn_bias                                          False
# train_bn                                             True
# moms                                   (0.95, 0.85, 0.95)
# cut                                                  None
# n_in                                                    3
# init         <function kaiming_normal_ at 0x7f49a9573be0>
# custom_head                                          None
# concat_pool                                          True
# lin_ftrs                                             None
# ps                                                    0.5
# pool                                                 True
# first_bn                                             True
# bn_final                                            False
# lin_first                                           False
# y_range                                              None

# %% [markdown]
# **Define model**

# %%
model = resnet34

# %% [markdown]
# **Define [metrics](https://docs.fast.ai/metrics.html)**

# %%
f1_macro = F1ScoreMulti(thresh=0.5, average='macro')
f1_macro.name = 'F1(macro)'
f1_samples = F1ScoreMulti(thresh=0.5, average='samples')
f1_samples.name = 'F1(samples)'
metrics = [partial(accuracy_multi, thresh=0.5), f1_macro, f1_samples]

# %% [markdown]
# **Define Learner object**

# %%
learn = vision_learner(dls, model, metrics=metrics).to_fp16()

# %% [markdown]
# **Find learning rate**

# %%
inspect_default_args(learn.lr_find)
# Out:
#                                      Default Value
# self                                          None
# start_lr                                       0.0
# end_lr                                          10
# num_it                                         100
# stop_div                                      True
# show_plot                                     True
# suggest_funcs  <function valley at 0x7f4990509750>

# %% [markdown]
# **Define [suggestion methods](https://docs.fast.ai/callback.schedule.html#Suggestion-Methods)**

# %%
suggest_funcs = [valley, minimum, steep]

# %%
learn.lr_find(suggest_funcs=suggest_funcs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0020892962347716093, minimum=0.03019951581954956, steep=0.033113110810518265)

# %% [markdown]
# **Define learning rate**

# %%
lr = 2e-2
lr
# Out:
# 0.02

# %% [markdown]
# **Define number of epochs**

# %%
epochs = 2

# %% [markdown]
# **Fine tune model**

# %%
inspect_default_args(learn.fine_tune)
# Out:
#               Default Value
# self                   None
# epochs                 None
# base_lr               0.002
# freeze_epochs             1
# lr_mult                 100
# pct_start               0.3
# div                     5.0
# lr_max                 None
# div_final          100000.0
# wd                     None
# moms                   None
# cbs                    None
# reset_opt             False

# %%
learn.fine_tune(epochs, base_lr=lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>F1(macro)</th>
#       <th>F1(samples)</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.710078</td>
#       <td>0.165122</td>
#       <td>0.949064</td>
#       <td>0.638056</td>
#       <td>0.707161</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>F1(macro)</th>
#       <th>F1(samples)</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.149951</td>
#       <td>0.173896</td>
#       <td>0.946056</td>
#       <td>0.553762</td>
#       <td>0.643514</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.127976</td>
#       <td>0.106405</td>
#       <td>0.962271</td>
#       <td>0.674986</td>
#       <td>0.715242</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Select a test image**

# %%
import PIL

# %%
files = get_image_files(path/'train')
files[0]
# Out:
# Path('/home/innom-dt/.fastai/data/pascal_2007/train/002034.jpg')

# %%
test_file = files[1]
test_file.name
# Out:
# '004259.jpg'

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %% [markdown]
# **Make a prediction on a single image using a file path**

# %%
learn.predict(test_file)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ((#2) ['chair','sofa'],
#  TensorBase([False, False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False,  True, False, False]),
#  TensorBase([5.9071e-04, 9.1105e-04, 5.8841e-04, 1.5012e-03, 9.4491e-03, 1.7892e-03,
#          8.7791e-03, 1.1028e-01, 6.6454e-01, 4.3315e-03, 1.7243e-02, 2.7638e-02,
#          1.7074e-03, 6.6670e-04, 2.7875e-01, 4.0586e-01, 1.2113e-03, 8.7451e-01,
#          2.7792e-03, 6.9164e-02]))

# %% [markdown]
# **Make a prediction on a single image using a [fastai.vision.core.PILImage](https://docs.fast.ai/vision.core.html#PILImage)**

# %%
learn.predict(PILImage(test_img))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ((#2) ['chair','sofa'],
#  TensorBase([False, False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False,  True, False, False]),
#  TensorBase([5.9071e-04, 9.1105e-04, 5.8841e-04, 1.5012e-03, 9.4491e-03, 1.7892e-03,
#          8.7791e-03, 1.1028e-01, 6.6454e-01, 4.3315e-03, 1.7243e-02, 2.7638e-02,
#          1.7074e-03, 6.6670e-04, 2.7875e-01, 4.0586e-01, 1.2113e-03, 8.7451e-01,
#          2.7792e-03, 6.9164e-02]))

# %% [markdown]
# **Make a prediction on a single image using a [fastai.torch_core.tensor](https://docs.fast.ai/torch_core.html#tensor)**

# %%
learn.predict(tensor(test_img))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ((#2) ['chair','sofa'],
#  TensorBase([False, False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False,  True, False, False]),
#  TensorBase([5.9071e-04, 9.1105e-04, 5.8841e-04, 1.5012e-03, 9.4491e-03, 1.7892e-03,
#          8.7791e-03, 1.1028e-01, 6.6454e-01, 4.3315e-03, 1.7243e-02, 2.7638e-02,
#          1.7074e-03, 6.6670e-04, 2.7875e-01, 4.0586e-01, 1.2113e-03, 8.7451e-01,
#          2.7792e-03, 6.9164e-02]))

# %%
learn.dls.vocab
# Out:
# ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

# %%
[category for detected, category in zip(learn.predict(test_file)[1], learn.dls.vocab) if detected]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ['chair', 'sofa']

# %% [markdown]
# **Make predictions for a group of images**

# %%
inspect_default_args(learn.show_results)
# Out:
#         Default Value
# self             None
# ds_idx              1
# dl               None
# max_n               9
# shuffle          True

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Define an Interpretation object**

# %%
inspect_default_args(Interpretation.from_learner)
# Out:
#        Default Value
# cls             None
# learn           None
# ds_idx             1
# dl              None
# act             None

# %%
interp = Interpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Plot top losses**

# %%
inspect_default_args(interp.plot_top_losses)
# Out:
#         Default Value
# self             None
# k                None
# largest          True

# %%
interp.plot_top_losses(k=9, figsize=(15,10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/fastai/torch_core.py:476: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ax = ax.append(pd.Series({label: o}))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>predicted</th>
#       <th>probabilities</th>
#       <th>loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bird</td>
#       <td>aeroplane</td>
#       <td>TensorBase([9.9999e-01, 1.3082e-06, 3.0634e-03, 1.5207e-05, 2.1445e-05, 4.1986e-05,\n        4.0606e-04, 1.0511e-06, 1.4739e-05, 1.4739e-05, 4.2647e-05, 8.7143e-07,\n        2.3139e-06, 3.6479e-05, 4.2646e-03, 2.0463e-05, 9.4613e-05, 1.1102e-06,\n        4.3569e-06, 4.7101e-04])</td>
#       <td>0.8494507074356079</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cat;chair;diningtable</td>
#       <td>bottle</td>
#       <td>TensorBase([5.8748e-05, 2.1486e-04, 2.7803e-04, 1.6357e-03, 7.7628e-01, 2.7900e-03,\n        3.2603e-03, 6.5388e-03, 1.0987e-02, 1.0902e-03, 1.1508e-02, 2.8449e-03,\n        1.4270e-03, 3.2987e-03, 1.3263e-01, 3.4975e-01, 4.1569e-04, 2.0993e-03,\n        9.4491e-03, 3.9343e-02])</td>
#       <td>0.8072366714477539</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cat;chair</td>
#       <td>bird</td>
#       <td>TensorBase([9.9153e-05, 4.6011e-04, 9.8434e-01, 4.7285e-04, 1.5906e-02, 2.8685e-04,\n        1.0608e-03, 4.6292e-02, 8.2314e-04, 1.2208e-03, 5.4634e-04, 6.1690e-03,\n        1.3459e-03, 4.8406e-04, 2.5311e-03, 8.6442e-03, 6.4631e-03, 8.6261e-04,\n        1.4539e-04, 6.5388e-03])</td>
#       <td>0.7191530466079712</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>chair;diningtable;person</td>
#       <td>person;train</td>
#       <td>TensorBase([1.5968e-04, 1.0328e-02, 9.1461e-04, 6.9868e-04, 9.1105e-04, 3.0215e-02,\n        1.9744e-01, 4.1246e-04, 1.1915e-02, 1.5731e-03, 3.2251e-04, 1.4381e-03,\n        8.5113e-03, 1.7961e-03, 7.9085e-01, 1.9985e-02, 4.8030e-04, 9.6975e-04,\n        7.2086e-01, 5.7032e-04])</td>
#       <td>0.7137547135353088</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>horse;person</td>
#       <td>pottedplant</td>
#       <td>TensorBase([7.2366e-04, 8.0937e-02, 3.8786e-01, 4.1340e-03, 1.0735e-02, 1.2241e-02,\n        1.3795e-02, 2.1166e-02, 1.4010e-02, 1.2147e-02, 1.0611e-02, 3.6358e-03,\n        6.9576e-03, 2.9312e-02, 2.0139e-02, 9.8446e-01, 6.7189e-03, 2.8119e-03,\n        1.3956e-02, 2.9579e-03])</td>
#       <td>0.6885901093482971</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bicycle;bus;car;person</td>
#       <td>train</td>
#       <td>TensorBase([4.4770e-04, 3.0297e-04, 2.1319e-04, 1.9267e-03, 4.8596e-04, 2.8497e-01,\n        1.0762e-01, 1.2054e-04, 3.3244e-03, 4.9942e-04, 1.8235e-04, 5.3075e-05,\n        1.0444e-03, 7.7029e-04, 3.4301e-01, 4.3994e-03, 4.4249e-04, 1.4426e-04,\n        6.6476e-01, 1.0363e-03])</td>
#       <td>0.6882683634757996</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>bicycle;person</td>
#       <td>aeroplane</td>
#       <td>TensorBase([9.4469e-01, 4.1085e-04, 9.7354e-04, 9.2852e-02, 7.3218e-04, 4.3610e-02,\n        1.7413e-01, 1.7131e-04, 2.4439e-03, 3.8096e-03, 9.8886e-04, 3.1504e-04,\n        5.2338e-04, 2.9235e-03, 6.7917e-02, 2.5910e-03, 1.0818e-02, 2.6948e-04,\n        3.9608e-03, 5.3433e-03])</td>
#       <td>0.6872835159301758</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>boat;person</td>
#       <td>pottedplant</td>
#       <td>TensorBase([2.7587e-04, 4.4858e-03, 2.9235e-03, 1.7780e-02, 1.2432e-02, 2.6011e-03,\n        6.0739e-03, 2.4377e-02, 2.0834e-01, 2.5115e-03, 8.6016e-02, 1.3564e-03,\n        1.0368e-02, 1.0735e-02, 4.5353e-02, 9.9766e-01, 1.2994e-03, 1.1556e-01,\n        1.8021e-02, 9.1610e-03])</td>
#       <td>0.6862831115722656</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>car;person;tvmonitor</td>
#       <td>car</td>
#       <td>TensorBase([7.4113e-06, 8.9345e-04, 9.0615e-07, 9.0750e-04, 4.0378e-05, 5.5189e-05,\n        9.9933e-01, 6.0018e-06, 3.1016e-04, 3.8529e-05, 4.0695e-05, 2.7109e-05,\n        1.6188e-05, 1.6062e-05, 5.1463e-02, 2.0184e-04, 1.2243e-04, 3.5081e-05,\n        1.3982e-04, 3.9136e-05])</td>
#       <td>0.6558526158332825</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.dls.after_batch
# Out:
# Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} -> Flip -- {'size': 224, 'mode': 'bilinear', 'pad_mode': 'reflection', 'mode_mask': 'nearest', 'align_corners': True, 'p': 0.5} -> Brightness -- {'max_lighting': 0.2, 'p': 1.0, 'draw': None, 'batch': False} -> Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)}

# %%
learn.dls.vocab
# Out:
# ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

# %% [markdown]
# **Reset test image**

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
test_img.size
# Out:
# (500, 375)

# %%
min(test_img.size)
# Out:
# 375

# %%
min_dim = test_img.size.index(min(test_img.size))
max_dim = 1 - min_dim

# %%
target_dim = 224

# %% [markdown]
# **Set input dims**

# %%
inp_dims = [0,0]
inp_dims[min_dim] = target_dim
inp_dims[max_dim] = int(test_img.size[max_dim] / (test_img.size[min_dim]/target_dim))
inp_dims
# Out:
# [298, 224]

# %%
resized_img = test_img.resize(inp_dims)
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=298x224>

# %% [markdown]
# **Convert image to tensor**

# %%
img_tensor = tensor(resized_img).permute(2, 0, 1)
img_tensor.shape, img_tensor
# Out:
# (torch.Size([3, 224, 298]),
#  tensor([[[125, 125, 125,  ...,  89,  89,  88],
#           [127, 126, 128,  ...,  90,  89,  89],
#           [127, 127, 128,  ...,  92,  91,  90],
#           ...,
#           [ 36,  41,  38,  ..., 109,  98,  80],
#           [ 33,  42,  40,  ...,  73,  63,  57],
#           [ 35,  41,  82,  ...,  53,  44,  51]],
#
#          [[ 80,  80,  80,  ...,  30,  30,  29],
#           [ 82,  81,  83,  ...,  30,  28,  30],
#           [ 82,  82,  83,  ...,  32,  30,  29],
#           ...,
#           [ 31,  26,  31,  ...,  57,  44,  30],
#           [ 30,  28,  32,  ...,  32,  23,  21],
#           [ 34,  29,  73,  ...,  20,  19,  32]],
#
#          [[ 41,  41,  41,  ...,   1,   1,   0],
#           [ 43,  42,  43,  ...,   1,   0,   0],
#           [ 43,  43,  43,  ...,   2,   1,   0],
#           ...,
#           [ 15,  15,  18,  ...,  17,   9,   5],
#           [ 13,  15,  19,  ...,   5,   2,  11],
#           [ 16,  15,  58,  ...,   0,   7,  33]]], dtype=torch.uint8))

# %% [markdown]
# **Scale tensor values**

# %%
scaled_tensor = img_tensor.float().div_(255)

# %% [markdown]
# **Prepare imagenet mean values**

# %%
mean_tensor = tensor(imagenet_stats[0]).view(1,1,-1).permute(2, 0, 1)
mean_tensor.shape, mean_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]))

# %% [markdown]
# **Prepare imagenet std values**

# %%
std_tensor = tensor(imagenet_stats[1]).view(1,1,-1).permute(2, 0, 1)
std_tensor.shape, std_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]))

# %% [markdown]
# **Normalize and batch image tensor**

# %%
normalized_tensor = (scaled_tensor - mean_tensor) / std_tensor
batched_tensor = normalized_tensor.unsqueeze(dim=0)
batched_tensor.shape, batched_tensor
# Out:
# (torch.Size([1, 3, 224, 298]),
#  tensor([[[[ 0.0227,  0.0227,  0.0227,  ..., -0.5938, -0.5938, -0.6109],
#            [ 0.0569,  0.0398,  0.0741,  ..., -0.5767, -0.5938, -0.5938],
#            [ 0.0569,  0.0569,  0.0741,  ..., -0.5424, -0.5596, -0.5767],
#            ...,
#            [-1.5014, -1.4158, -1.4672,  ..., -0.2513, -0.4397, -0.7479],
#            [-1.5528, -1.3987, -1.4329,  ..., -0.8678, -1.0390, -1.1418],
#            [-1.5185, -1.4158, -0.7137,  ..., -1.2103, -1.3644, -1.2445]],
#
#           [[-0.6352, -0.6352, -0.6352,  ..., -1.5105, -1.5105, -1.5280],
#            [-0.6001, -0.6176, -0.5826,  ..., -1.5105, -1.5455, -1.5105],
#            [-0.6001, -0.6001, -0.5826,  ..., -1.4755, -1.5105, -1.5280],
#            ...,
#            [-1.4930, -1.5805, -1.4930,  ..., -1.0378, -1.2654, -1.5105],
#            [-1.5105, -1.5455, -1.4755,  ..., -1.4755, -1.6331, -1.6681],
#            [-1.4405, -1.5280, -0.7577,  ..., -1.6856, -1.7031, -1.4755]],
#
#           [[-1.0898, -1.0898, -1.0898,  ..., -1.7870, -1.7870, -1.8044],
#            [-1.0550, -1.0724, -1.0550,  ..., -1.7870, -1.8044, -1.8044],
#            [-1.0550, -1.0550, -1.0550,  ..., -1.7696, -1.7870, -1.8044],
#            ...,
#            [-1.5430, -1.5430, -1.4907,  ..., -1.5081, -1.6476, -1.7173],
#            [-1.5779, -1.5430, -1.4733,  ..., -1.7173, -1.7696, -1.6127],
#            [-1.5256, -1.5430, -0.7936,  ..., -1.8044, -1.6824, -1.2293]]]]))

# %% [markdown]
# **Pass tensor to model**

# %%
with torch.no_grad():
    preds = learn.model(batched_tensor.cuda())
preds
# Out:
# TensorBase([[-7.6048, -6.7335, -7.2357, -6.5883, -4.4282, -5.9284, -4.8033, -2.0770,
#           1.2779, -5.6383, -3.3867, -3.8092, -5.6117, -7.2148, -2.2382,  0.0566,
#          -6.7994,  1.4810, -5.7877, -2.0524]], device='cuda:0')

# %%
rescaled_preds = torch.nn.functional.sigmoid(preds)
rescaled_preds
# Out:
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# TensorBase([[4.9780e-04, 1.1890e-03, 7.1990e-04, 1.3745e-03, 1.1795e-02, 2.6556e-03,
#          8.1358e-03, 1.1135e-01, 7.8208e-01, 3.5461e-03, 3.2715e-02, 2.1685e-02,
#          3.6417e-03, 7.3508e-04, 9.6371e-02, 5.1414e-01, 1.1132e-03, 8.1472e-01,
#          3.0555e-03, 1.1381e-01]], device='cuda:0')

# %%
[category for confidence, category in zip(rescaled_preds[0], learn.dls.vocab) if confidence > 0.2]
# Out:
# ['chair', 'pottedplant', 'sofa']

# %% [markdown]
# **Define ONNX file name**

# %%
onnx_file_name = f"{path.name}-{learn.arch.__name__}.onnx"
onnx_file_name
# Out:
# 'pascal_2007-resnet34.onnx'

# %% [markdown]
# **Export trained model to ONNX**

# %%
torch.onnx.export(learn.model.cpu(),
                  batched_tensor,
                  onnx_file_name,
                  export_params=True,
                  opset_version=9,
                  do_constant_folding=True,
                  input_names = ['input'],
                  output_names = ['output'],
                  # Uncomment the line below to unlock input dimensions
                  #dynamic_axes={'input': {2 : 'height', 3 : 'width'}}
                 )
